# %%
import pandas as pd

df = pd.read_csv('output.csv')
df.head(n=200)
# Out:
#            date state  positive    death  days_since_first
# 0    2021-03-07    AK   56886.0    305.0               375
# 1    2021-03-07    AL  499819.0  10148.0               375
# 2    2021-03-07    AR  324818.0   5319.0               375
# 3    2021-03-07    AS       0.0      0.0               375
# 4    2021-03-07    AZ  826454.0  16328.0               375
# ..          ...   ...       ...      ...               ...
# 195  2021-03-04    OH  974480.0  17189.0               372
# 196  2021-03-04    OK  426641.0   4534.0               372
# 197  2021-03-04    OR  156287.0   2252.0               372
# 198  2021-03-04    PA  941439.0  24219.0               372
# 199  2021-03-04    PR  100867.0   2053.0               372
#
# [200 rows x 5 columns]

# %%
subset_df = df[df['days_since_first'] == 375]
subset_df = subset_df.sort_values('death', ascending=False)

subset_df.head(n=5)
# Out:
#           date state   positive    death  days_since_first
# 9   2021-03-07    FL  1909209.0  32266.0               375
# 39  2021-03-07    PA   948643.0  24349.0               375
# 33  2021-03-07    NJ   812609.0  23574.0               375
# 15  2021-03-07    IL  1198335.0  23014.0               375
# 10  2021-03-07    GA  1023487.0  17906.0               375

# %%
subset_df = subset_df.sort_values('positive', ascending=False)
subset_df.head(n=5)
#visualize FL, PA, IL
# Out:
#           date state   positive    death  days_since_first
# 9   2021-03-07    FL  1909209.0  32266.0               375
# 15  2021-03-07    IL  1198335.0  23014.0               375
# 10  2021-03-07    GA  1023487.0  17906.0               375
# 36  2021-03-07    OH   978471.0  17656.0               375
# 39  2021-03-07    PA   948643.0  24349.0               375

# %%
fl_df = df[df['state'] == 'FL']
import matplotlib.pyplot as plt

# %%
plt.scatter(fl_df['days_since_first'], fl_df['death'])
plt.xlabel('Days since first')
plt.ylabel('Counts')
plt.title('FL Death')
plt.show()
plt.scatter(fl_df['days_since_first'], fl_df['positive'])
plt.xlabel('Days since first')
plt.ylabel('Positive')
plt.title('FL Positive')
plt.show()

# %%
pa_df = df[df['state'] == 'PA']
plt.scatter(pa_df['days_since_first'], pa_df['death'])
plt.xlabel('Days since first')
plt.ylabel('Counts')
plt.title('PA Death')
plt.show()
plt.scatter(pa_df['days_since_first'], pa_df['positive'])
plt.xlabel('Days since first')
plt.ylabel('Positive')
plt.title('PA Positive')
plt.show()

# %%
il_df = df[df['state'] == 'IL']
plt.scatter(il_df['days_since_first'], il_df['death'])
plt.xlabel('Days since first')
plt.ylabel('Counts')
plt.title('IL Death')
plt.show()
plt.scatter(il_df['days_since_first'], il_df['positive'])
plt.xlabel('Days since first')
plt.ylabel('Positive')
plt.title('IL Positive')
plt.show()
